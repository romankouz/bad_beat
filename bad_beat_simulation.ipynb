# %%
import numpy as np
import itertools as it
from thpoker.core import * # Combo, Hand, Table

from collections import Counter

# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.5

# %% [markdown]
# # Create a Deck of Cards

# %%
class Deck:
    
    def __init__(self):
        self.cards = []
        self.deck_dict = {}
        for value in ["2","3","4","5","6","7","8","9","T","J","Q","K","A"]:
            for suit in ["h","d","c","s"]:
                self.cards.append(value + suit)
        for card in self.cards:
            self.deck_dict[Card(card)] = card
        for bottom_straight in ["1s","1d","1c","1h"]:
            self.deck_dict[Card(bottom_straight)] = "A" + bottom_straight[1]

# %%
test = Deck()
test.deck_dict
# Out:
# {2♥: '2h',
#  2♦: '2d',
#  2♣: '2c',
#  2♠: '2s',
#  3♥: '3h',
#  3♦: '3d',
#  3♣: '3c',
#  3♠: '3s',
#  4♥: '4h',
#  4♦: '4d',
#  4♣: '4c',
#  4♠: '4s',
#  5♥: '5h',
#  5♦: '5d',
#  5♣: '5c',
#  5♠: '5s',
#  6♥: '6h',
#  6♦: '6d',
#  6♣: '6c',
#  6♠: '6s',
#  7♥: '7h',
#  7♦: '7d',
#  7♣: '7c',
#  7♠: '7s',
#  8♥: '8h',
#  8♦: '8d',
#  8♣: '8c',
#  8♠: '8s',
#  9♥: '9h',
#  9♦: '9d',
#  9♣: '9c',
#  9♠: '9s',
#  T♥: 'Th',
#  T♦: 'Td',
#  T♣: 'Tc',
#  T♠: 'Ts',
#  J♥: 'Jh',
#  J♦: 'Jd',
#  J♣: 'Jc',
#  J♠: 'Js',
#  Q♥: 'Qh',
#  Q♦: 'Qd',
#  Q♣: 'Qc',
#  Q♠: 'Qs',
#  K♥: 'Kh',
#  K♦: 'Kd',
#  K♣: 'Kc',
#  K♠: 'Ks',
#  A♥: 'Ah',
#  A♦: 'Ad',
#  A♣: 'Ac',
#  A♠: 'As',
#  1♠: 'As',
#  1♦: 'Ad',
#  1♣: 'Ac',
#  1♥: 'Ah'}

# %% [markdown]
# # Creating a Class for an NLH Table

# %%
class NLHTable:
    
    def __init__(self, n_seats=9):
        self.n_seats = n_seats
        
    def deal_hand(self):
        
        # deal to each player
        card_deck = Deck().cards
        dealt_cards = np.random.choice(card_deck, 2*self.n_seats, replace=False)
        hands = [dealt_cards[i:(i+2)] for i in range(0, 2*self.n_seats, 2)]
        
        
        # deal the runout
        cards_left = list(it.chain(*[ [k]*v for k,v in (Counter(card_deck) - Counter(dealt_cards)).items() ]))
        board = np.random.choice(cards_left, 5, replace=False)
        
        return hands, board
    
    def quads_or_better(self, hand, board):
        hand_eval = "/".join(hand)
        board_eval = "/".join(board)
        five_card_hand = Combo(hand=Hand(hand_eval), table=Table(board_eval))
        five_card_hand_as_str = [Deck().deck_dict[card_as_str] for card_as_str in five_card_hand.cards]
        # this ensures that the correct hand is achieved AND that both whole cards are in play
        if five_card_hand.name in ['four of a kind', 'straight flush'] and all([Deck().deck_dict[Card(whole_card)] in five_card_hand_as_str for whole_card in hand]):
            return True
        return False
    
    def bad_beat_hit(self, hands, board):
        for hand in hands:
            # check if a bad beat has been hit for a hand dealt
            pass

# %%
hands, board = NLHTable(9).deal_hand()
hands, board
# Out:
# ([array(['6d', 'Qs'], dtype='<U2'),
#   array(['2d', 'Qc'], dtype='<U2'),
#   array(['5d', 'Tc'], dtype='<U2'),
#   array(['Ah', '7c'], dtype='<U2'),
#   array(['7h', 'Qd'], dtype='<U2'),
#   array(['8d', 'Kd'], dtype='<U2'),
#   array(['4d', '4s'], dtype='<U2'),
#   array(['6h', 'Jd'], dtype='<U2'),
#   array(['Ac', 'Td'], dtype='<U2')],
#  array(['Th', '9d', 'Kc', '8h', '3s'], dtype='<U2'))

# %% [markdown]
# # Test High Hand Qualifications

# %%
# this is just 4 of a kind aces
hand1 = ["Ah", "As"]
board1 = ["Ac","Ad","Kd","2d","3s"]

# this is NOT a proper bad beat hand because you do not use 
# both whole cards to make your five card hand (AAAAK)
hand2 = ["Ah", "2s"]
board2 = ["Ac","Ad","Kd","2d","3s"]

# While this is not a pocket pair, the Ace DOES play in 
# the five card hand (3333A) so this qualifies for bad beat
hand3 = ["3h", "As"]
board3 = ["3c","3d","Kd","2d","3s"]

# this a straight flush requiring both whole cards and should work
hand4 = ["3h", "4h"]
board4 = ["5h","9d","6h","2d","7h"]

# this a straight flush NOT requiring both whole cards and should work
hand5 = ["3h", "As"]
board5 = ["5h","4h","6h","2d","7h"]

# this is the hand a fish plays
hand6 = ["3h", "4s"]
board6 = ["Tc","9d","Kd","2d","8s"]

hand7 = ['4s', '3h']
board7 = ['6s', '5s', '3s', 'Tc', '7s']

assert NLHTable().quads_or_better(hand1, board1)
assert not NLHTable().quads_or_better(hand2, board2)
assert NLHTable().quads_or_better(hand3, board3)
assert NLHTable().quads_or_better(hand4, board4)
assert not NLHTable().quads_or_better(hand5, board5)
assert not NLHTable().quads_or_better(hand6, board6)
assert not NLHTable().quads_or_better(hand7, board7)

# %% [markdown]
# # Creating the Simulation

# %%
def bad_beat_simulation(n_tables=1000, n_hands=100000):
    bad_beat_list = []
    hand_counter = 0
    bad_beat_counter = 0
    while hand_counter <= n_hands:
        for table in range(n_tables):
            current_table = NLHTable()
            hands, board = current_table.deal_hand()
            current_table_high_hand_counter = 0
            for hand in hands:
                if current_table.quads_or_better(hand, board):
                    current_table_high_hand_counter += 1
                    print(hand, board)
                if current_table_high_hand_counter >= 2:
                    bad_beat_counter += 1
                    bad_beat_list.append((hands, board))
                    # this break is important because it is possible that 3 hands qualify for bad beat
                    # but we only want to count this as 1 bad beat because the jackpot doesn't get
                    # paid out twice in this EXTREMELY rare situation
                    break
        hand_counter += n_tables
        print(hand_counter)
    return bad_beat_counter, bad_beat_counter/n_hands, bad_beat_list

# %%
bad_beat_simulation()
# Out:
# ['Qh' 'Qd'] ['6d' '7h' 'Qs' 'Qc' '3c']
# ['Ks' 'Js'] ['As' 'Ts' 'Qs' 'Qh' 'Ah']
# ['7h' '7d'] ['7c' '4s' 'Qc' '6d' '7s']
# ['Ac' 'As'] ['Ad' '8d' 'Kh' 'Qc' 'Ah']
# ['9c' '9s'] ['Qs' '9d' '5c' '9h' 'Js']
# ['Tc' '7c'] ['Jd' '9c' '8c' '6c' 'Qd']
# ['6c' '6d'] ['6s' 'Qc' '6h' 'Js' 'Kd']
# ['Ts' 'Th'] ['Tc' 'Td' '8c' '2s' '9s']
# ['3d' '3h'] ['3c' '3s' '5d' '6s' '7s']
# 1000
# ['Jh' 'Kh'] ['2c' '7s' 'Js' 'Jd' 'Jc']
# 2000
# ['Jc' 'Kd'] ['Jd' '4c' '4s' 'Jh' 'Js']
# ['As' 'Th'] ['Td' 'Ac' 'Tc' 'Ts' '3h']
# ['5d' '5c'] ['2c' 'Jc' '5h' '6s' '5s']
# ['2c' '2d'] ['2s' '3h' 'Js' '9h' '2h']
# ['2h' '2s'] ['8d' 'Jc' 'Jd' '2d' '2c']
# ['Jd' 'Kd'] ['Jh' '6h' '7s' 'Jc' 'Js']
# ['3c' '3s'] ['3d' '3h' '9c' 'Td' '9s']
# ['9c' '8c'] ['9h' '9d' '4d' '5d' '9s']
# ['2c' '3c'] ['7d' '5c' '9h' 'Ac' '4c']
# ['4h' '4d'] ['4s' '2s' '4c' '8h' '8c']
# ['Jh' 'Qs'] ['Qc' '7h' 'Qh' 'Qd' 'Th']
# 3000
# ['6c' 'Jh'] ['3s' '5c' '6d' '6s' '6h']
# ['Ah' 'Ac'] ['As' '5d' 'Ad' '4c' '7h']
# ['As' 'Ac'] ['Ah' 'Ad' 'Kh' 'Kd' '3s']
# ['Jh' 'Jc'] ['7d' 'Js' 'Th' '8s' 'Jd']
# ['Qs' 'Jc'] ['Tc' 'Jd' '3d' 'Jh' 'Js']
# ['5s' '5d'] ['Qd' '5c' 'Kc' '6d' '5h']
# ['Qh' '6c'] ['6d' 'Qd' '6h' '6s' '5c']
# ['2c' '5c'] ['3c' 'Jh' '4c' '6c' '7s']
# ['Jh' 'Jc'] ['Js' 'Jd' 'Td' '2c' '7h']
# ['Kd' 'Ks'] ['Kh' 'Kc' 'Jh' '7c' '2d']
# ['Ac' 'Kc'] ['Kd' 'As' '5c' 'Kh' 'Ks']
# ['6h' '8h'] ['9h' '7h' 'Qs' '5s' 'Th']
# 4000
# ['Td' 'Tc'] ['8c' 'Ah' 'Th' 'As' 'Ts']
# ['As' '9h'] ['9s' '9c' '9d' 'Qh' 'Qc']
# ['As' '4d'] ['7s' '4c' '4s' '4h' '8s']
# ['Qs' '5h'] ['5c' 'Jh' '5s' '9c' '5d']
# ['6c' '6h'] ['6d' '6s' 'Kh' 'Jc' 'Th']
# ['4s' '4d'] ['Kc' '3c' 'Ks' '4h' '4c']
# ['4s' '4d'] ['4c' '8h' '4h' '3c' '2d']
# ['Kc' 'Qc'] ['8h' 'Kd' 'Qd' 'Qh' 'Qs']
# ['Ah' 'Jh'] ['2s' 'Ac' 'As' 'Ts' 'Ad']
# ['7s' '7h'] ['3s' '2c' '7d' 'Kd' '7c']
# ['Jc' 'Jh'] ['Js' 'Jd' '5h' '6h' 'Kc']
# ['Js' '5h'] ['3c' '5d' '5c' '4h' '5s']
# ['3h' '3s'] ['3c' 'Td' 'Tc' '3d' '8s']
# 5000
# ['4d' '4c'] ['4h' '9d' 'Kc' '4s' '8h']
# ['Qd' 'Qc'] ['Qs' 'Kh' '9h' 'Qh' 'Td']
# ['Js' 'As'] ['Ah' 'Ad' '4d' 'Ac' '3h']
# ['8h' '9h'] ['4c' '5h' '7h' '6h' '7c']
# ['8s' 'Jh'] ['8h' '2d' '4c' '8d' '8c']
# ['7c' 'Js'] ['Jh' '5h' 'Jc' '4c' 'Jd']
# ['Jd' 'Jc'] ['Qd' 'Jh' 'Js' '7c' 'Ks']
# 6000
# ['8c' '7d'] ['5c' '7s' '7c' '7h' '6d']
# ['5h' '5c'] ['Qh' 'Qs' '9s' '5s' '5d']
# ['Qs' 'Ks'] ['Qh' '6s' '2d' 'Qc' 'Qd']
# ['9c' 'Qh'] ['9d' '4d' '9s' 'Ts' '9h']
# ['As' 'Ac'] ['6c' '7c' 'Ah' 'Ad' '3d']
# ['6h' '6s'] ['6c' '5c' '7d' '2h' '6d']
# ['3c' '3d'] ['2s' '3h' '5s' '3s' 'Th']
# ['Jc' '6c'] ['4h' '6d' '6s' '6h' '7h']
# ['Th' 'Tc'] ['Td' '8d' '3h' 'Ts' '2s']
# ['5h' 'Th'] ['8h' '5c' '5d' '5s' '8c']
# ['2h' 'Ah'] ['5h' '9s' '8d' '3h' '4h']
# 7000
# ['4c' '4s'] ['8h' '4d' 'Th' 'Jc' '4h']
# ['Qs' '9s'] ['Ts' 'Js' '6d' '8s' 'Ks']
# ['As' '8s'] ['8d' '8h' '6h' '8c' '9h']
# ['Ah' 'Qs'] ['Ad' 'Ac' '4s' 'Td' 'As']
# ['Kc' 'Kd'] ['Kh' 'Js' '2h' 'Ks' '4s']
# ['4c' 'Th'] ['5s' '4d' '4h' '8s' '4s']
# ['Qd' 'Ah'] ['Qh' 'Qc' 'Qs' '3h' 'Ac']
# ['Qh' 'Kc'] ['Kh' 'Kd' '8h' 'Qs' 'Ks']
# 8000
# ['Ac' 'Ad'] ['Jd' 'Ah' 'As' 'Ks' 'Ts']
# ['Qs' 'Qd'] ['Qc' 'Jc' '7d' 'Qh' '9c']
# ['Kc' 'Td'] ['8s' 'Jc' 'Tc' 'Th' 'Ts']
# ['3h' 'Ad'] ['3c' '5c' '6h' '3s' '3d']
# ['Kh' 'Kd'] ['Tc' 'Kc' 'Jc' 'Ks' '6h']
# ['7h' '4s'] ['4c' '4h' '5h' '4d' '6d']
# ['Kd' '3s'] ['3h' 'Tc' '5c' '3c' '3d']
# ['6h' '6d'] ['8h' '6c' 'Tc' '6s' 'Qc']
# ['4c' '4s'] ['Jc' '4d' 'Ac' '4h' '7s']
# ['9h' '9s'] ['6h' '9d' '9c' '6s' 'Kd']
# ['Ac' 'Ah'] ['3c' 'Ad' 'As' '4h' '3h']
# 9000
# ['3c' '3h'] ['3d' '7c' '9d' '3s' '9s']
# ['Qs' 'Kh'] ['Kc' 'Ks' 'Tc' '2c' 'Kd']
# ['Qd' '5h'] ['5s' '5c' 'Jc' '5d' '6c']
# ['9h' '9s'] ['9d' '9c' '3c' '7d' '6c']
# ['Jc' '9c'] ['9s' '2s' '9h' '2h' '9d']
# ['Th' 'Td'] ['7s' '9s' '2c' 'Tc' 'Ts']
# ['5s' '3s'] ['4s' 'Kc' '7s' '3d' '6s']
# ['2s' '2d'] ['2h' '4h' '2c' '9d' 'Th']
# ['7d' '4d'] ['Ac' '5d' '5h' '8d' '6d']
# ['3c' 'Ah'] ['3h' '6c' 'Jh' '3s' '3d']
# 10000
# ['7s' '7c'] ['6d' '9c' '7d' 'Ad' '7h']
# ['Qs' 'Qc'] ['5c' 'Qd' '8d' 'Qh' 'Ah']
# ['Tc' 'Th'] ['Qh' 'Td' '9d' 'Ts' '4c']
# ['7s' '6s'] ['4s' '3s' '2c' '2d' '5s']
# ['6s' '9s'] ['8s' '7s' '5s' '3d' '8h']
# ['7d' '9d'] ['Jh' '2c' '8d' 'Td' '6d']
# ['3s' 'Qc'] ['3c' '3h' '2c' '3d' '5c']
# ['Ts' '9h'] ['9c' '2c' '8c' '9s' '9d']
# 11000
# ['3h' 'As'] ['5h' '3c' '3d' '3s' '2s']
# ['As' 'Ah'] ['Ac' 'Jh' 'Ad' '6c' '5c']
# ['Kc' 'Qh'] ['2s' 'Ts' 'Qc' 'Qs' 'Qd']
# ['5s' 'Ad'] ['9s' '5h' '5c' '5d' 'Jc']
# ['7c' '9c'] ['9h' '9d' '5h' '5d' '9s']
# ['9d' 'Ks'] ['Kc' 'Kh' '3h' '7d' 'Kd']
# ['7d' 'Jc'] ['3c' '7s' '7h' '7c' '3s']
# 12000
# ['Kd' 'Kc'] ['6s' 'Kh' 'Ks' '7d' '2c']
# ['7s' 'Kh'] ['3s' '7d' 'Qc' '7h' '7c']
# ['Th' 'Jd'] ['8h' 'Js' 'Tc' 'Ts' 'Td']
# ['8s' 'Ts'] ['9s' '7s' '5s' '4d' 'Js']
# ['Jh' '8d'] ['Jc' 'Js' '8c' '4h' 'Jd']
# ['7c' '7d'] ['7s' 'Ah' '7h' 'Tc' 'Jc']
# ['9d' 'Qh'] ['Qs' '3h' 'Qc' 'Qd' '2s']
# ['Ad' 'Ah'] ['5d' 'Ac' '9h' '7d' 'As']
# 13000
# ['Td' 'Js'] ['Jc' 'Jd' '7d' 'Jh' '6s']
# ['Kh' 'Ks'] ['Jd' 'Kc' '2d' 'Kd' '3h']
# ['4d' 'Qd'] ['Ts' '4h' '4c' '4s' '3h']
# ['8h' '8s'] ['6s' '8d' 'Th' 'Kc' '8c']
# ['As' 'Js'] ['Qs' 'Ad' '6h' 'Ks' 'Ts']
# ['6c' '6h'] ['6s' '6d' 'Jd' '5s' '5c']
# ['Qh' 'Qs'] ['2c' 'Jh' 'Qd' 'Ac' 'Qc']
# ['8s' '8d'] ['4h' '8c' 'Ah' '7s' '8h']
# 14000
# ['Ad' 'Ac'] ['8s' 'As' 'Kh' 'Ah' 'Jd']
# ['9d' 'Td'] ['2c' '4d' 'Tc' 'Th' 'Ts']
# ['Kc' 'Ac'] ['Kh' 'Ks' 'Ts' 'Tc' 'Kd']
# ['9s' '2d'] ['5s' '2h' '3h' '2c' '2s']
# ['6d' '9d'] ['8d' '9c' 'Td' '7d' '3c']
# ['4c' '4h'] ['9c' '4s' '5c' '4d' 'Ac']
# 15000
# ['8s' '8h'] ['8c' 'Qd' 'Qc' 'As' '8d']
# ['9c' '9h'] ['Kd' '3s' '9d' '8d' '9s']
# ['6c' '6d'] ['5d' '6s' 'Ac' '8h' '6h']
# ['Ah' 'Qd'] ['Ac' 'As' 'Ad' 'Td' '7s']
# ['5c' '5s'] ['Jd' '8c' '5d' '5h' 'Kh']
# ['Qs' 'Qc'] ['3s' 'Jh' '7s' 'Qh' 'Qd']
# ['Ad' '5d'] ['8h' '2d' 'Jh' '3d' '4d']
# ['Tc' 'Td'] ['Th' 'Ts' '8c' '4c' '2d']
# 16000
# ['Ac' 'Kd'] ['Kh' 'Kc' 'Ks' '9s' '9h']
# ['As' '7c'] ['7s' '5h' 'Ac' '7d' '7h']
# ['7c' '4h'] ['6h' '4c' '4s' '4d' '2h']
# ['8h' '3s'] ['3c' '6d' '3h' '3d' '4h']
# ['Tc' 'Th'] ['Ts' 'Td' '5c' '8c' '2c']
# ['Ac' '8s'] ['8c' 'Qs' '5s' '8d' '8h']
# ['8s' '8h'] ['8c' '2d' '8d' 'Js' '6d']
# ['Qh' 'Kh'] ['Qs' 'Qc' '4s' 'Qd' '6c']
# 17000
# ['Jh' 'Qc'] ['Qs' 'Qh' '8c' 'Qd' '3s']
# ['Ts' 'Qh'] ['Qd' 'Qc' '4c' 'Qs' '7h']
# ['9s' '9h'] ['5d' '9c' '7h' 'Tc' '9d']
# ['Js' 'Kc'] ['Ks' 'Kd' '8c' 'Kh' '8h']
# ['8c' 'Jc'] ['9c' 'Th' '2s' '7c' 'Tc']
# ['Kc' 'Kh'] ['Ks' 'Kd' '7s' '4s' 'Ts']
# ['4d' '4h'] ['5s' 'Kd' '4c' '4s' 'Ac']
# ['Ts' 'Kd'] ['6h' 'Th' 'Td' 'Tc' '8s']
# ['3s' '3h'] ['4c' '3c' '3d' 'Kc' 'Ac']
# ['Tc' 'As'] ['Td' 'Th' '7d' 'Ts' '3c']
# 18000
# ['5h' '3h'] ['2h' '9d' '6h' 'Qd' '4h']
# ['5d' '5s'] ['5c' '2s' '5h' '6d' 'Kc']
# ['Ts' 'Qs'] ['9s' '9d' '8s' 'Js' 'Ac']
# ['Jh' 'Jd'] ['Ad' 'Jc' '6c' '5c' 'Js']
# ['Qc' 'Qs'] ['5c' '3c' 'Qh' '7d' 'Qd']
# ['Qs' 'Qh'] ['Jd' 'Qd' '9h' 'Qc' 'Kc']
# ['8s' '8d'] ['Ts' '6h' '9d' '8c' '8h']
# 19000
# ['Ks' '6s'] ['6c' '6h' '8s' '6d' '4c']
# ['3c' '6c'] ['4c' 'Ks' '7h' '5c' '7c']
# ['9h' 'Qh'] ['Jh' 'Th' '4c' '5c' '8h']
# ['5s' '5d'] ['Ah' 'Ac' '7c' '5c' '5h']
# ['6h' '6c'] ['7d' '3c' '6d' '7s' '6s']
# ['4h' '4d'] ['4c' 'Ad' '5s' '4s' 'Js']
# ['Kd' 'Td'] ['Ts' 'Th' 'Tc' '8c' '9s']
# ['7s' '9s'] ['8s' 'Js' 'Ts' '5h' 'Ad']
# ['Kh' 'Qh'] ['6h' 'Qd' 'Qs' 'Qc' '5h']
# ['Qh' 'Tc'] ['Th' '8h' '6h' 'Td' 'Ts']
# ['Kh' '9h'] ['7s' '8c' 'Qh' 'Jh' 'Th']
# ['Kh' '8s'] ['8c' '8h' '7s' '8d' '7d']
# 20000
# ['Jd' 'Jh'] ['4c' '2d' 'Js' 'Jc' 'Kh']
# ['7d' '7s'] ['9h' '5h' '7h' '7c' 'Qd']
# ['8d' '6d'] ['9d' '7d' '5c' '5d' 'Ah']
# ['Kh' '5d'] ['Jc' '5c' '5h' '5s' '7d']
# ['Ts' '6d'] ['6h' '7s' '6s' 'Th' '6c']
# 21000
# ['5h' '5d'] ['2c' 'Tc' '5s' '9s' '5c']
# ['4c' 'Ad'] ['4d' '8c' '4s' '4h' '6d']
# ['Qh' 'Th'] ['Ah' '4h' 'Kh' 'Jh' '9s']
# ['8c' '5c'] ['4d' '6h' '5d' '5h' '5s']
# ['3s' '3d'] ['3h' '2s' '3c' '4d' '9s']
# ['Ts' '6s'] ['3d' 'Td' 'Tc' 'Th' '4s']
# ['7s' '7c'] ['5d' 'Qs' '7h' 'Kc' '7d']
# ['Qs' 'Qc'] ['6h' 'Qh' 'Tc' 'Js' 'Qd']
# ['7c' '8c'] ['5c' '4c' 'Ts' '7h' '6c']
# ['5h' 'Kc'] ['9h' '5s' '5c' '6c' '5d']
# ['9c' '9h'] ['9d' '8h' '5c' 'Td' '9s']
# ['Ah' '9h'] ['3c' 'Ac' 'As' 'Ad' '8h']
# 22000
# ['6s' '6c'] ['Qd' '6h' '6d' 'Tc' 'Ts']
# ['3s' '3c'] ['7d' '3d' '3h' '2c' '7c']
# ['7s' '6s'] ['Jc' '5s' '4s' '8s' '8h']
# ['Th' 'Td'] ['Ks' '3h' 'Ts' 'Ah' 'Tc']
# ['8h' 'Jh'] ['Th' '7h' '3h' '9h' 'As']
# ['Kh' 'Ad'] ['Ks' 'Th' '3h' 'Kd' 'Kc']
# ['5h' '5d'] ['Ac' '5c' 'Qc' '5s' '6s']
# 23000
# ['Jh' 'Jc'] ['9d' 'Ac' 'Js' 'Jd' '2c']
# ['Td' 'Ts'] ['Th' 'Ah' '5d' '6s' 'Tc']
# ['6h' '6c'] ['6s' '2d' 'Qd' '2s' '6d']
# ['Th' 'Tc'] ['Jh' 'Td' 'Kh' '9h' 'Ts']
# ['Ah' '5d'] ['Ad' '2d' 'As' 'Ac' '2s']
# ['Qd' '6c'] ['4d' '6h' '6s' 'Jc' '6d']
# ['2d' '2h'] ['2c' '4d' '2s' '9h' '6d']
# 24000
# ['5d' '5h'] ['5c' '7d' '6c' 'Kd' '5s']
# ['Qc' 'Tc'] ['Qs' 'Qh' '6d' '8c' 'Qd']
# ['3d' '3s'] ['Js' '3c' '3h' 'Kc' 'Td']
# ['Qc' '9c'] ['3h' '2d' '8c' 'Tc' 'Jc']
# ['As' '9h'] ['2h' '9s' '9c' '9d' 'Ac']
# 25000
# ['Td' 'Ts'] ['Qh' '3c' '7c' 'Tc' 'Th']
# ['7c' '8c'] ['4c' '6c' 'Kd' '8d' '5c']
# ['7s' '7c'] ['7d' '3s' 'Qs' '7h' '9c']
# ['6d' 'Jh'] ['6c' '2h' '6s' '6h' '7d']
# 26000
# ['9h' 'Ks'] ['9s' 'Jc' '9d' '9c' '8d']
# ['Jc' 'Jd'] ['7d' '8d' 'Js' 'Qc' 'Jh']
# ['Jc' 'Js'] ['Jh' 'Jd' '5s' '5d' '8c']
# ['8d' '9s'] ['7d' '8h' '8s' '2h' '8c']
# ['5c' 'Ks'] ['Kh' 'Kc' '2c' 'Kd' '3s']
# ['Ac' 'Ah'] ['Ad' 'Jd' '3c' 'As' '8c']
# ['Qs' 'Qc'] ['5s' '7h' 'Qh' 'Qd' 'Tc']
# ['6d' 'Ac'] ['Td' '9s' '6s' '6c' '6h']
# ['6d' '7h'] ['5s' '7c' '7d' '3d' '7s']
# ['7s' '9s'] ['9d' '9c' '3h' '7h' '9h']
# 27000
# ['As' 'Td'] ['Ts' '4s' 'Th' 'Tc' '4d']
# ['Qs' 'Qc'] ['Qd' 'Qh' '9h' '4c' 'Jh']
# ['Qc' 'Qd'] ['8s' '6h' 'Kc' 'Qs' 'Qh']
# ['7h' 'Jc'] ['5h' 'Jd' '5c' 'Js' 'Jh']
# ['Jd' 'Js'] ['Jh' '3s' 'Jc' 'Kc' '6c']
# ['2c' 'Kd'] ['2s' '8c' '2h' '6c' '2d']
# 28000
# ['Ac' 'Ah'] ['2d' '3d' 'As' '8s' 'Ad']
# ['9c' '7c'] ['9h' '6s' 'Tc' 'Jc' '8c']
# ['Jc' 'As'] ['Jh' '6d' 'Jd' 'Js' 'Tc']
# ['Qs' 'Qd'] ['Td' 'Qh' '3s' 'Qc' 'Kc']
# ['Ts' 'Th'] ['8c' '9c' 'Tc' 'Kc' 'Td']
# ['Qs' '5c'] ['7c' '5s' '6d' '5h' '5d']
# ['6h' '6s'] ['Qd' '6c' '6d' '4s' 'Qs']
# ['9d' '9s'] ['3c' '3s' '9h' '7h' '9c']
# 29000
# ['Ad' 'Qh'] ['7s' 'As' 'Ac' 'Qs' 'Ah']
# ['4s' '4d'] ['9s' '4h' 'Ah' 'Js' '4c']
# ['8c' '8h'] ['8d' '5s' 'Th' '8s' '9h']
# ['Js' 'Ac'] ['Jd' '4c' 'Ah' 'Jc' 'Jh']
# ['3c' '3s'] ['3d' 'Th' '8h' '3h' 'Ad']
# ['3d' '3s'] ['3h' '3c' '6d' '2s' 'Td']
# ['6c' '6d'] ['Ah' 'Th' '6h' '6s' '5s']
# ['Ah' '3c'] ['As' 'Ad' '2d' '3h' 'Ac']
# ['7h' 'Jh'] ['6d' 'Qc' 'Th' '8h' '9h']
# ['Td' 'Th'] ['8s' '2c' 'Ts' 'Kc' 'Tc']
# 30000
# ['8h' '8d'] ['Jc' '9d' '8s' 'Th' '8c']
# ['7c' '5c'] ['4s' '8c' '9c' '9d' '6c']
# ['7h' '9h'] ['8c' '4c' '7d' '7s' '7c']
# ['6h' '6s'] ['8h' '4c' '6d' '3c' '6c']
# ['6s' 'Ts'] ['8s' '7s' 'Ah' '9s' '2h']
# ['Ad' 'Ah'] ['4d' '6c' 'Js' 'As' 'Ac']
# ['Qd' '6s'] ['4d' '6h' '6d' 'Td' '6c']
# ['7d' '7c'] ['7s' '6c' 'Ts' '7h' '4s']
# ['Tc' 'Td'] ['Qc' 'Jd' 'Th' 'Jc' 'Ts']
# ['8s' '8h'] ['Ad' 'Ah' 'Qd' '8c' '8d']
# ['4s' '6c'] ['4h' '4d' '6h' '3h' '4c']
# 31000
# ['Qd' 'Js'] ['Qc' 'Qh' 'Qs' '5d' '3c']
# ['4d' 'Ts'] ['3h' 'Th' '4c' 'Tc' 'Td']
# ['7s' '6s'] ['Ts' 'Jd' '8s' '9s' 'Ah']
# ['6d' '6c'] ['2d' 'Kd' '6s' '6h' 'Js']
# ['8d' '8h'] ['Qh' '9d' '8s' '8c' '5s']
# ['Tc' 'Jc'] ['8c' '9c' '7c' '6h' '5c']
# ['7d' '7c'] ['7s' '5c' '7h' 'Qs' '9s']
# ['8c' '8h'] ['7h' '6s' '2d' '8s' '8d']
# ['4s' '2s'] ['6s' '3s' '8c' '5s' '9c']
# ['8s' 'Qs'] ['3c' 'Qh' 'Qc' 'Qd' '5s']
# ['2c' '5c'] ['3c' 'Js' 'Th' '6c' '4c']
# ['Jc' 'Jh'] ['2s' '2h' 'Jd' 'Ad' 'Js']
# ['Kh' '4c'] ['4d' 'Tc' '4h' '5d' '4s']
# ['Th' 'Ts'] ['Kh' 'Js' 'Td' 'Tc' '2s']
# ['9s' 'Qc'] ['9h' '9d' '9c' '5d' 'Th']
# 32000
# ['5h' '5d'] ['5s' '4h' 'Td' 'Js' '5c']
# ['Ad' '7c'] ['7d' '7h' '4c' 'As' '7s']
# ['7d' 'Ac'] ['Ad' '6s' 'As' 'Ah' '5d']
# ['2h' '2s'] ['2c' '8s' '6c' '2d' 'As']
# ['5d' '9d'] ['Js' 'Ts' '6d' '8d' '7d']
# 33000
# ['3d' '5d'] ['6d' '2c' '7d' '6c' '4d']
# ['Tc' 'Kd'] ['Th' 'Ts' '2s' 'Td' 'Ks']
# ['8d' 'Tc'] ['8s' '5s' '8c' '6d' '8h']
# ['4h' '5h'] ['6h' '2h' '6s' '3h' 'Js']
# ['6d' '5d'] ['Kh' '4d' '3d' 'Ah' '2d']
# ['Tc' 'Jc'] ['6d' 'Jh' 'Qc' 'Kc' 'Ac']
# ['Ad' 'Kh'] ['As' '2d' 'Ac' 'Ah' '9d']
# ['Ac' 'Jd'] ['Jc' 'Js' 'Kh' 'Jh' '9s']
# ['Ac' '6d'] ['Ad' 'Ah' '2s' 'As' '4d']
# ['Ac' 'Ah'] ['2c' 'Ad' '2s' '6d' 'As']
# 34000
# ['5c' '5h'] ['Ks' '9c' '3c' '5s' '5d']
# ['9h' 'Tc'] ['9s' '6s' '5c' '9d' '9c']
# ['Qd' 'Qh'] ['Qs' '7h' 'Qc' 'Tc' 'Kc']
# ['Kc' '8d'] ['8h' '8s' 'Qh' '7c' '8c']
# ['7d' 'Td'] ['3h' 'Th' 'Ts' '4s' 'Tc']
# ['Ad' '7h'] ['7s' '7c' '5c' '7d' '4h']
# ['Ts' 'Ah'] ['As' '5s' 'Th' 'Tc' 'Td']
# ['As' 'Ad'] ['Ks' 'Ah' 'Ac' '4c' 'Tc']
# ['Th' 'Tc'] ['Td' 'Qc' 'Ts' '4d' 'Ac']
# 35000
# ['9s' '9d'] ['As' '9h' '7c' '9c' 'Qd']
# ['6h' '6s'] ['7h' '3d' '6c' '6d' '8h']
# ['6s' '6d'] ['Jh' 'Ks' '6h' '2c' '6c']
# ['Kc' 'Kh'] ['8c' 'Jd' 'As' 'Ks' 'Kd']
# ['9d' '2c'] ['6d' '2h' '4h' '2d' '2s']
# ['9s' '8s'] ['Js' '6c' 'Qs' '9h' 'Ts']
# ['3h' '3d'] ['Kc' '3s' 'Kh' '3c' '7h']
# 36000
# ['6h' '6c'] ['6s' '9h' 'Qd' '7c' '6d']
# ['4h' '4d'] ['4s' '6c' 'Jd' '4c' 'Ac']
# ['5c' 'Ac'] ['5h' 'Kd' '5s' '9d' '5d']
# ['6s' '8s'] ['6h' '4h' '6c' '5h' '6d']
# ['8c' '8d'] ['Qs' 'As' '8h' '6s' '8s']
# ['9d' '7d'] ['4s' '7c' '7s' '7h' '2d']
# ['7c' '4c'] ['Jh' '5c' '6c' '3c' '4s']
# ['2d' '2s'] ['7s' 'Qd' '2h' '2c' '4d']
# ['3h' '3c'] ['3s' '8d' '3d' 'Qh' 'Kd']
# ['3d' 'Jd'] ['3s' 'Tc' '3h' '9h' '3c']
# 37000
# ['Kc' '6c'] ['6d' '9h' '6s' '6h' '5h']
# ['6s' '6d'] ['6h' '2s' 'Qd' '6c' '2d']
# ['Tc' 'Ts'] ['2c' 'Th' 'Jh' '2d' 'Td']
# ['4h' '4s'] ['4d' 'Kd' '4c' 'Jc' '5c']
# ['3s' '2s'] ['3c' '5s' 'As' '2d' '4s']
# ['Ah' 'Ac'] ['Ad' 'As' 'Qd' '6d' '8h']
# ['Kh' 'Ks'] ['Kd' 'Qd' 'Kc' 'Js' '3h']
# ['8d' '8s'] ['8c' '7h' '9h' '7c' '8h']
# ['5d' 'Ac'] ['5s' '5c' 'Ah' 'Qs' '5h']
# ['2c' '2d'] ['2s' '2h' '3h' '6s' '9d']
# 38000
# ['4d' '4s'] ['4h' '4c' '8d' '3h' 'Kc']
# ['4h' '6h'] ['7h' '8h' '6s' '5h' 'Js']
# ['Ad' 'Ac'] ['5d' 'Ah' '3c' 'As' '2c']
# ['6s' 'Qs'] ['2h' '6h' '3s' '6d' '6c']
# ['7s' '6s'] ['5h' '8s' 'Ts' '9s' 'Qh']
# ['8s' 'Qh'] ['Jd' '8c' '3d' '8d' '8h']
# ['2s' '2h'] ['6d' '2d' '2c' '9h' '7s']
# 39000
# ['6c' 'Ac'] ['Ad' '6d' '6s' 'Td' '6h']
# ['9d' '9s'] ['9c' '9h' '4c' '6c' '4d']
# ['5c' '5s'] ['5h' 'Qd' '9s' 'Tc' '5d']
# ['Qs' 'Ah'] ['Ac' 'As' '6d' 'Ad' '2s']
# ['2s' '2h'] ['2c' '6s' '5d' 'Ad' '2d']
# ['Kd' '2c'] ['2h' '2s' '4c' '5s' '2d']
# 40000
# ['Ah' 'As'] ['9s' '7d' 'Ad' '5s' 'Ac']
# ['Ks' 'Ac'] ['Kh' 'Kc' 'Kd' '8c' '4d']
# ['Td' 'Ts'] ['Tc' '6h' 'Th' '3h' 'Jd']
# ['Qc' 'Qs'] ['Qh' 'Qd' '3d' '9s' 'Th']
# ['Tc' 'Jc'] ['8d' 'Kc' 'Qc' '9c' '7s']
# ['5d' 'Ad'] ['2d' 'Jc' '8d' '3d' '4d']
# 41000
# ['5d' '5s'] ['5c' 'Th' 'Qd' '5h' '9c']
# ['Qs' 'Qd'] ['9c' '7h' '5s' 'Qh' 'Qc']
# ['Qc' 'Qh'] ['9c' 'Qd' '8s' 'Qs' 'Js']
# ['8s' 'Kd'] ['9h' '8d' 'Qd' '8c' '8h']
# ['Th' 'Kh'] ['Tc' 'Ts' '5h' 'Td' '3s']
# ['Jh' '9s'] ['3s' '9c' '9d' 'Js' '9h']
# ['Th' 'Jh'] ['Ac' '7h' '8h' '9h' 'Ts']
# ['2c' '3c'] ['Kh' '4c' '3s' '5c' 'Ac']
# ['Ad' 'As'] ['8s' '5d' 'Ac' '8d' 'Ah']
# ['4s' '3s'] ['2h' '4h' '5s' '7s' '6s']
# ['3d' '3h'] ['7s' '5c' '8h' '3c' '3s']
# 42000
# ['4h' '9c'] ['4c' '4d' '6d' '4s' '5d']
# ['7h' '7d'] ['Qh' '5d' '7s' '7c' '2h']
# ['Jh' 'Jc'] ['Jd' '4h' 'Js' '7c' '4d']
# ['9d' '9c'] ['Js' '9s' '9h' 'Ac' '5d']
# ['Kd' 'Js'] ['3c' '9h' 'Jc' 'Jh' 'Jd']
# ['9c' '9s'] ['3s' 'Jc' '9h' 'Qd' '9d']
# 43000
# ['5d' '5h'] ['7c' '5c' 'Kh' 'Ah' '5s']
# ['8d' '9h'] ['9s' '8s' '9c' '9d' '6s']
# ['Qh' '9s'] ['9h' '5d' '5s' '9d' '9c']
# ['7d' '5d'] ['3d' '4d' 'Jc' '6d' 'Ac']
# ['4s' '4h'] ['4d' '4c' 'Ah' '9s' 'Js']
# ['9d' '9h'] ['Ah' '3s' '9c' '6s' '9s']
# ['Js' 'Qd'] ['Jd' '2h' 'Jh' '6d' 'Jc']
# ['7s' '7d'] ['7h' '7c' '9d' '9s' 'Kh']
# ['4c' '3c'] ['5h' 'Ac' '5c' '6c' '7c']
# ['Kd' 'Kh'] ['Kc' '9d' 'Ac' 'Ks' '7d']
# 44000
# ['8s' 'Ts'] ['7s' '9s' '2d' '6s' 'Qs']
# ['Td' 'Th'] ['Tc' '4h' '4d' 'Ts' '3s']
# ['4s' 'Td'] ['4h' '4c' '4d' '7c' '9d']
# ['6c' '6h'] ['2s' '6d' '4h' '2c' '6s']
# ['2h' '2c'] ['3d' '9s' '2s' '6s' '2d']
# ['6s' '6c'] ['9d' '6d' '2d' '6h' '5s']
# ['4s' '4c'] ['4h' '6d' '4d' 'Kd' 'Js']
# ['Qh' 'Qs'] ['Qd' 'Qc' 'Td' '7s' '4h']
# ['5d' '5h'] ['Ah' '9d' '8s' '5c' '5s']
# 45000
# ['Td' '8h'] ['8s' '2c' '8d' '4s' '8c']
# ['4d' '4c'] ['8h' 'Ts' '4h' '9s' '4s']
# ['3s' '3d'] ['3h' 'Qs' 'Th' '3c' '2s']
# ['Kc' '8s'] ['2c' '8d' 'Qh' '8h' '8c']
# ['Kd' 'Kc'] ['Qd' 'Ks' '7s' '8h' 'Kh']
# ['Jc' 'Js'] ['Jh' '5d' 'Jd' 'Kh' '3s']
# ['5c' '5d'] ['5s' '5h' 'Ad' 'Qh' '9h']
# ['8c' '9h'] ['9d' '9c' '9s' '5s' '4h']
# ['9s' 'Qs'] ['Ts' 'Js' '2c' 'Jc' '8s']
# 46000
# ['Ad' 'Kd'] ['Jd' '7c' 'Td' '9d' 'Qd']
# ['9c' 'Ad'] ['9s' '3c' '9d' '9h' '8s']
# ['5c' '5s'] ['5d' '5h' '4h' '9h' '7c']
# ['9c' '9h'] ['9s' 'Ac' '9d' 'Td' '2d']
# ['Jc' '9h'] ['9s' '5s' '9d' '9c' '2s']
# ['7c' '3s'] ['3c' '3d' '6d' '3h' '4s']
# ['9s' '9h'] ['Tc' 'Jd' '9c' '5c' '9d']
# ['Tc' 'Ac'] ['Qc' '5c' 'Kc' 'Jc' '9s']
# 47000
# ['Ad' 'As'] ['9d' '4h' 'Ah' 'Ac' '6s']
# ['Ks' 'Qh'] ['Qs' 'Qd' '5h' 'Qc' 'Jh']
# ['Jc' '4d'] ['Jh' '4h' '4s' '3s' '4c']
# ['Td' 'Th'] ['Ts' '9c' 'Tc' '9h' 'Qc']
# ['9d' '9h'] ['Kh' '9c' '9s' '8c' '2c']
# ['5h' '8h'] ['7h' '6h' '6d' '9h' 'Kd']
# ['6h' '6s'] ['2h' '6c' 'Ac' '6d' '3c']
# 48000
# ['Ad' 'Ah'] ['Ac' 'Th' 'Kc' 'As' 'Ks']
# ['Tc' 'Kc'] ['Ah' 'Ac' 'Ad' 'Jc' 'Qc']
# ['5h' '5c'] ['Kh' '6s' 'Ts' '5d' '5s']
# ['4s' 'Qd'] ['Jd' '9s' '4c' '4h' '4d']
# ['Qd' 'Qs'] ['Jc' 'Qc' 'As' 'Qh' '5h']
# ['9c' '9s'] ['As' '9h' '9d' '7d' '5s']
# ['Qh' '7d'] ['Qs' '7h' '3c' 'Qc' 'Qd']
# ['9d' '8d'] ['6s' '7d' '6d' 'Td' '9h']
# ['Kd' 'Ks'] ['3d' 'Kh' 'Kc' '6s' 'Qc']
# 49000
# ['6h' '8d'] ['8s' '5c' '6c' '8h' '8c']
# ['Jh' 'Jd'] ['5h' '5d' 'Qh' 'Jc' 'Js']
# ['Jh' 'Th'] ['6s' '7h' '9h' '4s' '8h']
# ['Th' 'Ts'] ['Qd' 'Tc' 'Td' 'Ad' 'Ac']
# 50000
# ['9s' 'Kc'] ['9h' '3d' '2s' '9c' '9d']
# ['Ah' '9s'] ['9h' '9c' '3d' '3s' '9d']
# ['9h' '9d'] ['Ah' '9c' '9s' '7h' '5c']
# ['7d' '8d'] ['6d' '5s' 'Ad' '5d' '4d']
# ['Th' 'Kh'] ['Jh' 'Ah' '7d' 'Kd' 'Qh']
# ['7s' '7d'] ['Qc' '7h' '9s' 'Jc' '7c']
# ['Qs' '8s'] ['2c' 'Qd' 'Qc' '4h' 'Qh']
# ['7c' 'Ks'] ['Kd' 'Kc' 'Kh' '3c' '2s']
# ['3d' '3c'] ['Qd' 'Kc' '5h' '3h' '3s']
# ['5s' 'As'] ['4s' '8c' '3s' '2s' '2c']
# ['9c' '9h'] ['8d' '9s' 'Td' '9d' '6d']
# ['6c' '9c'] ['Tc' 'Ad' '2h' '8c' '7c']
# ['4d' '4h'] ['4c' 'Kd' '4s' '6c' '7h']
# 51000
# ['Ac' 'Ad'] ['Ks' 'As' 'Qc' 'Qd' 'Ah']
# ['Qc' 'Kc'] ['Kd' 'Ks' 'Kh' 'Js' '4d']
# ['3d' '6d'] ['2d' '5c' '4d' '5d' 'Ts']
# ['2c' '8c'] ['8d' '2h' '2s' '7s' '2d']
# ['5d' '5c'] ['Ac' 'Ad' '5h' 'Th' '5s']
# ['Tc' 'Kc'] ['Jc' '3h' 'Ac' 'Qc' '6d']
# ['Qh' '5c'] ['9d' '7d' '5h' '5d' '5s']
# ['Kh' 'Ac'] ['Kd' 'Ks' 'Kc' '7h' 'Qs']
# ['Ad' 'Qh'] ['Qs' '3h' 'Qd' 'Qc' 'Ks']
# 52000
# ['8c' 'Ah'] ['8s' '8h' '5h' '8d' '3s']
# ['Ac' 'As'] ['4h' '3s' '2c' 'Ah' 'Ad']
# ['5d' '5s'] ['3s' '2h' 'Kh' '5c' '5h']
# ['Kc' 'Kd'] ['Qc' 'Kh' 'Ks' '7c' 'Jd']
# ['Kc' 'Ks'] ['Kh' '5s' '2c' 'Jh' 'Kd']
# ['Th' 'Ts'] ['Tc' 'Ac' '9h' '4s' 'Td']
# ['Ad' '4d'] ['7c' '4c' '8s' '4s' '4h']
# ['3c' '3d'] ['Qh' '3s' '7d' 'Th' '3h']
# ['Tc' 'Th'] ['Kd' 'Kc' 'Ts' '9d' 'Td']
# ['8s' '8c'] ['8h' '2s' '2c' '8d' '5d']
# ['Qh' 'Qs'] ['2d' 'Ad' 'Qc' 'Qd' '6c']
# ['As' '3d'] ['3h' '8c' '7d' '3c' '3s']
# ['5c' '2c'] ['3d' 'Qd' '4c' '3c' 'Ac']
# ['Qs' 'Ah'] ['8d' 'Ad' 'Ac' 'As' 'Qd']
# 53000
# ['8h' '8d'] ['8s' '4d' '8c' 'Td' 'Qc']
# ['7d' '9d'] ['7s' '8d' 'Jd' 'Td' '4s']
# ['8d' '8c'] ['Kc' 'Ks' '8s' 'Td' '8h']
# ['Jd' 'Jc'] ['Qd' '4h' 'Ad' 'Js' 'Jh']
# ['Kd' '6h'] ['Jd' '6s' '6c' '6d' '2d']
# 54000
# ['Td' 'Tc'] ['Jh' '6c' '6s' 'Ts' 'Th']
# ['8c' '8s'] ['Jh' '8d' '2d' '7s' '8h']
# ['Qc' 'Qs'] ['Qh' 'Kd' '2s' '7d' 'Qd']
# ['Kd' 'Kh'] ['9h' 'Ks' '8s' 'Kc' '4d']
# ['Qc' 'Qs'] ['Qh' 'Qd' '8c' '2c' 'Js']
# ['6d' 'Ts'] ['6h' 'Th' 'Tc' 'Td' '5c']
# 55000
# ['4s' '5s'] ['2s' '6s' 'As' 'Ks' '3s']
# ['5s' '4s'] ['6s' '8s' 'Kh' '7s' 'Qs']
# ['9d' '7h'] ['3d' '9h' '9s' '9c' '5h']
# ['6d' 'Td'] ['9d' '5d' '5s' '8d' '7d']
# ['Kh' 'Ks'] ['Kc' 'Th' 'Kd' '2c' '6d']
# ['Th' 'Ts'] ['7d' 'Jh' 'Tc' 'Ac' 'Td']
# ['Th' 'Td'] ['9c' '6c' 'Jh' 'Ts' 'Tc']
# ['5d' '8h'] ['5c' '5s' '5h' '7d' '4d']
# ['Qs' 'Qc'] ['Jd' '7h' 'Qh' 'Ks' 'Qd']
# ['Td' '6d'] ['9c' '6h' '2s' '6c' '6s']
# 56000
# ['8h' '9h'] ['Jh' '8d' 'Th' '7h' '8c']
# ['6d' 'Td'] ['9d' '7d' 'Ac' '8h' '8d']
# ['Qs' '7c'] ['4h' 'Qd' 'Qh' 'Qc' '4d']
# ['Ts' '8s'] ['8c' '3s' '6s' '7s' '9s']
# ['7d' '5d'] ['8d' '9d' '6d' '8h' '7h']
# ['8c' '2d'] ['2s' '4s' '6s' '2c' '2h']
# ['7h' '7c'] ['7s' '3d' '7d' '4s' 'Th']
# ['4h' 'Ah'] ['5h' '3h' '2h' 'Qc' '2d']
# ['7h' '6h'] ['9h' '8h' '9s' '5h' '7s']
# ['8c' '5c'] ['Td' '6c' 'Th' '4c' '7c']
# 57000
# ['6c' '6h'] ['7d' '6s' 'Ah' '6d' '9h']
# ['6s' '8s'] ['5s' '7s' '9s' '7c' '8c']
# ['Qh' 'Qc'] ['8c' '4s' '7c' 'Qd' 'Qs']
# ['7c' '5c'] ['2s' '3c' '4c' '6h' '6c']
# ['Tc' 'Th'] ['8h' '6d' '3d' 'Td' 'Ts']
# ['5s' '6s'] ['3s' '7d' 'Ks' '7s' '4s']
# ['5c' '2c'] ['8d' '3c' '4c' 'Ac' 'Jd']
# ['Ac' '9d'] ['Js' '9c' '9h' '9s' '8c']
# ['5d' 'Kd'] ['Th' '5h' '5s' '5c' '2c']
# ['8h' 'Ad'] ['3s' '5s' 'As' 'Ac' 'Ah']
# 58000
# ['Qs' 'Th'] ['Qh' 'Ts' 'Qc' 'Qd' '7h']
# ['7h' '7d'] ['7s' '7c' 'Qc' '5s' 'Ac']
# ['5c' '4c'] ['Jc' '6c' '7c' 'Qs' '3c']
# ['Ah' '6h'] ['6d' '6c' 'Kc' '6s' '5d']
# ['7h' '7d'] ['7c' '8d' '4s' 'Jc' '7s']
# ['Qc' '3s'] ['3d' '3h' '4h' '3c' '9s']
# ['Qc' 'Qh'] ['6h' '6c' 'Qd' 'Qs' '9c']
# ['6c' '6s'] ['2d' '6d' '6h' '8s' 'Ad']
# ['7h' 'Td'] ['8c' '7c' '7d' '7s' '9c']
# ['Kh' 'Ks'] ['4d' '6c' 'Kc' '5c' 'Kd']
# 59000
# ['4h' '6d'] ['5h' '4d' '4c' '2d' '4s']
# ['8d' '6d'] ['7d' '4d' 'Ad' '5d' 'Ks']
# ['Jh' 'Td'] ['2d' 'Th' 'Tc' '2h' 'Ts']
# ['2c' '2s'] ['9s' '2d' 'Kc' 'Ad' '2h']
# ['4s' '4d'] ['4c' '5c' '6c' '4h' '7h']
# 60000
# ['Td' 'Ah'] ['7d' '3s' 'Ts' 'Tc' 'Th']
# ['5h' '5s'] ['2s' '7c' '3d' '5c' '5d']
# ['Qc' 'Ac'] ['Qd' '7c' 'Qh' 'Qs' 'Td']
# ['Ah' 'As'] ['Ts' '9s' '7d' 'Ac' 'Ad']
# ['Th' 'Ad'] ['Tc' 'Td' '2c' 'Ts' '3d']
# ['Ad' 'Qd'] ['Qs' '5d' 'Qc' 'Qh' '2h']
# ['5c' '5s'] ['5d' '5h' 'Td' '3s' 'Jh']
# ['8s' '8d'] ['Th' 'Jh' '8h' '8c' '4c']
# 61000
# ['Tc' '8d'] ['2h' '8h' '8c' '3d' '8s']
# ['7c' '7h'] ['7s' 'Kd' 'As' 'Ts' '7d']
# ['Jd' 'Ks'] ['Kd' 'Kh' 'Kc' '9h' '6d']
# ['9c' '9s'] ['2h' 'Kc' '6d' '9h' '9d']
# ['4s' '4d'] ['4c' '7h' '4h' '5s' 'Qc']
# ['3c' '3h'] ['Jh' '3s' 'Th' '3d' 'Js']
# ['Ac' 'Qh'] ['Qc' 'Qd' '6c' 'Qs' 'Jd']
# ['7h' '7s'] ['Ad' '7c' 'Qh' 'Qs' '7d']
# ['Qs' 'Kc'] ['Qh' 'Qc' 'Qd' '3c' 'Kh']
# ['Ks' 'Kh'] ['Qc' 'As' 'Kd' '9d' 'Kc']
# ['Td' '9h'] ['Th' '2h' 'Ts' 'Tc' '3c']
# ['9h' '6h'] ['7h' 'Th' '8h' '5s' '4c']
# 62000
# ['8h' '9h'] ['5c' '4h' 'Th' 'Jh' 'Qh']
# ['9d' '3c'] ['3s' '7s' '9h' '3d' '3h']
# ['7d' '7h'] ['5h' '7s' '8c' '9c' '7c']
# ['Jh' 'Th'] ['9h' '9d' 'Kh' '6c' 'Qh']
# ['6c' '6d'] ['Qc' '6h' '6s' 'Jh' 'Ac']
# ['9d' '9s'] ['9c' '9h' '6c' 'Td' 'Qh']
# 63000
# ['Jh' 'As'] ['Js' 'Jd' 'Jc' '2s' '5c']
# ['2s' '2c'] ['Qc' '2d' '5c' 'As' '2h']
# ['3s' 'Kc'] ['3h' '5s' '3d' '8d' '3c']
# ['6c' '5d'] ['2s' '5h' '5s' '5c' '3h']
# ['5d' 'Kh'] ['5h' '5c' '5s' 'Jd' 'Qc']
# ['2d' '2s'] ['9c' 'As' '2c' 'Th' '2h']
# ['Ac' '7h'] ['8s' '7s' '7c' '3d' '7d']
# ['9h' 'Jc'] ['5c' 'Jh' '6c' 'Jd' 'Js']
# ['9c' '3h'] ['3d' '7c' '3c' '9h' '3s']
# ['4s' '6s'] ['8s' '5s' '7d' '7s' '4c']
# ['Ts' '3h'] ['3c' '3d' '7c' '3s' '8h']
# 64000
# ['Kc' '5d'] ['7c' '5h' '5s' '5c' '6s']
# ['Qd' 'Qs'] ['Kc' '3d' '8h' 'Qh' 'Qc']
# ['Kd' 'Kh'] ['4c' '3c' 'Kc' 'Ks' 'Ts']
# ['Tc' '2d'] ['6d' '2c' '7s' '2h' '2s']
# ['As' 'Qs'] ['Ah' '6d' 'Ad' 'Ac' 'Jh']
# ['Qs' 'Td'] ['4c' 'Th' 'Tc' '2s' 'Ts']
# ['6h' '6c'] ['Ks' '2h' '6s' '4c' '6d']
# ['3d' '5d'] ['4d' 'Ks' '2d' '6d' 'Qs']
# ['2h' 'Ks'] ['2s' '2c' '2d' 'Qh' '5c']
# ['Th' 'Ts'] ['4h' '4c' 'Td' 'Tc' '6s']
# ['Kc' 'Ks'] ['Kd' '5c' 'Kh' 'Tc' '8h']
# 65000
# ['5h' '5s'] ['5d' '3d' '5c' 'Qh' '8c']
# ['Kd' 'Ad'] ['6h' '9h' 'Kc' 'Ks' 'Kh']
# ['3s' '3d'] ['4h' '3c' '3h' '7d' '4s']
# ['2h' '2d'] ['Kc' '2c' '2s' '3s' '7s']
# ['Kh' 'Kd'] ['Jd' '5c' '8d' 'Kc' 'Ks']
# ['5d' 'Ac'] ['5s' 'Jh' '5c' 'Jd' '5h']
# ['Qc' 'Qd'] ['9d' '5h' 'Qs' '3d' 'Qh']
# ['Ac' 'Qc'] ['Qd' 'Qs' '8h' '8d' 'Qh']
# ['Jd' 'Td'] ['9d' 'Qd' 'Ac' 'Kd' 'Kc']
# 66000
# ['Qh' 'Th'] ['Qs' '8d' '5c' 'Qd' 'Qc']
# ['7h' '7d'] ['7s' '9d' '2h' '6s' '7c']
# ['9c' '8c'] ['6c' '9d' '9h' '9s' '7h']
# ['Ah' 'Qs'] ['Ac' 'Qc' 'Ks' 'Qd' 'Qh']
# ['5d' '4d'] ['6s' '8c' 'Ad' '3d' '2d']
# ['Qh' '4c'] ['5s' '4d' '4h' '4s' '2h']
# ['9h' '6h'] ['8h' '7h' 'Jh' 'Qh' '5h']
# ['3h' '4h'] ['6h' 'Jc' '5h' '7s' '7h']
# ['6s' '8h'] ['8s' '3h' '8c' '2h' '8d']
# ['2d' '2h'] ['4d' '2c' '9s' 'Js' '2s']
# ['5s' '5h'] ['6d' '5c' '6h' '5d' '9s']
# ['Kd' 'Ks'] ['Kh' 'Ts' '9d' 'Qc' 'Kc']
# ['2d' '2s'] ['2h' '4d' 'Qc' 'Kd' '2c']
# ['5h' '7h'] ['4h' '8h' '6h' 'Td' '2s']
# ['6s' '6c'] ['4c' '5d' '7s' '6h' '6d']
# 67000
# ['5d' '5c'] ['5s' '9h' '5h' '7s' 'Tc']
# ['2s' '2d'] ['2c' '4s' '2h' 'Ts' '7d']
# ['As' 'Kd'] ['Td' '9s' 'Ks' 'Kc' 'Kh']
# ['6d' '6h'] ['6c' 'Kc' 'Kh' 'Kd' '6s']
# ['Ts' '9s'] ['7s' 'Kd' 'Jh' 'Js' '8s']
# ['9d' 'Jd'] ['Td' '8d' '7d' '9c' 'Jc']
# ['Qs' 'Js'] ['Ts' '9d' '3h' '9s' 'Ks']
# ['Jd' 'Js'] ['9c' 'Jh' '5s' 'Jc' '6s']
# ['Td' 'Ad'] ['Jd' 'Th' 'Ts' 'Tc' 'Qh']
# ['9d' 'As'] ['9s' '9h' '9c' '8d' 'Ts']
# ['Kh' 'Kc'] ['Kd' 'Ks' '6c' '5c' 'Ad']
# ['2d' 'Qc'] ['2s' 'Tc' '2h' '8s' '2c']
# 68000
# ['8s' 'Ts'] ['Js' '2d' '7d' '9s' '7s']
# ['As' '5s'] ['Qh' '2s' '3s' '4s' '9h']
# ['9s' '9d'] ['4c' '9c' '9h' '3c' '8h']
# ['Ts' 'Js'] ['Ks' '9s' 'Qs' '7d' '6d']
# ['6c' '4c'] ['5s' '5c' '3c' '7c' 'Ad']
# ['Jd' 'Js'] ['Jh' 'Qd' 'Kd' 'Qc' 'Jc']
# ['6c' '7c'] ['Ac' 'Th' '9c' '8c' '5c']
# ['3c' '4c'] ['8s' '5c' '2c' '2d' 'Ac']
# 69000
# ['Qh' 'Qs'] ['Qd' '2c' 'Qc' '4c' 'Th']
# ['9s' '7c'] ['9d' '9h' '9c' '7s' '4c']
# ['8h' '7d'] ['8c' '5d' '8d' '5h' '8s']
# ['2h' '2s'] ['2c' '8c' '6c' 'Kd' '2d']
# ['5c' '5s'] ['Qc' '5d' '7h' '5h' 'Kc']
# ['8c' '7s'] ['7h' '7d' '4c' '7c' '2s']
# ['7s' '7c'] ['7d' '7h' 'Ts' '8d' '2c']
# 70000
# ['8d' 'Ac'] ['5h' '8s' 'Kh' '8h' '8c']
# ['Qc' 'Kh'] ['9c' 'Kc' 'Kd' 'Ks' '5s']
# ['2h' '3h'] ['Ks' '4h' '8c' '6h' '5h']
# ['6d' '6h'] ['As' 'Ad' '6c' '6s' '4s']
# ['4c' '4s'] ['Td' '4d' '5h' 'Ts' '4h']
# ['As' 'Qs'] ['Qd' '5h' 'Ah' 'Ac' 'Ad']
# ['8d' 'Jc'] ['9d' 'Tc' '8s' '8c' '8h']
# ['7d' 'Tc'] ['7h' '4c' '5h' '7c' '7s']
# ['6c' '6d'] ['Jd' '6s' '5d' 'Tc' '6h']
# ['9c' 'Ah'] ['9s' '9d' '6h' 'Qd' '9h']
# 71000
# ['Ks' 'Kh'] ['2d' 'Ad' 'Kc' '7h' 'Kd']
# ['3d' '2d'] ['4d' '6d' 'Ks' '5d' 'Jh']
# ['Jh' 'Kh'] ['Qh' '9h' 'Jc' '7c' 'Th']
# ['Qd' 'Js'] ['5h' 'Qc' '7h' 'Qh' 'Qs']
# ['5h' '5d'] ['5c' 'Qd' '5s' '8s' '2h']
# ['5d' 'Jh'] ['9h' '5s' '5h' '3c' '5c']
# ['Ts' 'Tc'] ['Td' 'Jh' 'Th' '7h' 'Ad']
# ['Ts' '8s'] ['5c' '9s' 'Qs' '5h' 'Js']
# ['Ad' 'Kc'] ['Kd' 'Ks' 'Qs' '2h' 'Kh']
# ['6c' '6h'] ['6s' 'As' '6d' '8d' '5s']
# ['Qd' 'Qh'] ['9h' '7c' '7h' 'Qs' 'Qc']
# ['9d' 'Ad'] ['Ac' '2s' 'As' 'Ah' '9c']
# 72000
# ['7s' '7h'] ['7c' '2d' '2s' '7d' 'Ks']
# ['Th' 'Tc'] ['Ts' 'Qs' 'Kd' 'Td' '6s']
# ['7c' 'As'] ['7d' '7s' '3c' 'Jd' '7h']
# ['4d' '4h'] ['Qc' '4c' '6d' '4s' '7h']
# ['3c' 'Ad'] ['5s' '2d' '3d' '3h' '3s']
# ['9s' 'Kc'] ['4c' 'Ks' 'Kh' '8d' 'Kd']
# ['5h' '5c'] ['5d' '5s' 'Ac' 'Jc' 'Ah']
# 73000
# ['6d' 'Td'] ['9c' '9d' '7d' '2h' '8d']
# ['8c' '9c'] ['Kh' '7c' 'Tc' '4c' '6c']
# ['9h' 'Qh'] ['Kh' '6d' 'Th' 'Jh' 'Td']
# ['Th' 'Ad'] ['9h' 'Td' 'Tc' '4h' 'Ts']
# ['Qh' '8s'] ['Qc' 'Qd' 'Qs' '6d' '3h']
# ['Qs' 'Kd'] ['7h' 'Qd' 'Kc' 'Qc' 'Qh']
# 74000
# ['9c' 'Ah'] ['9d' '9s' '8c' '9h' '3c']
# ['Kh' 'Kd'] ['Kc' '7c' '8d' 'Ks' 'Tc']
# ['3h' '5h'] ['9c' 'Ks' '6h' '2h' '4h']
# ['6h' '7h'] ['3h' '4c' '5h' 'Ac' '4h']
# ['5d' '6d'] ['7d' 'Qd' '2c' '3d' '4d']
# ['Ks' '4c'] ['4h' '6s' '4s' '9d' '4d']
# ['7s' '7c'] ['7h' 'Tc' '3d' 'Th' '7d']
# 75000
# ['9c' 'Ac'] ['9h' '9d' '2c' '9s' '3d']
# ['8d' '6d'] ['7d' '7s' '4d' 'Qd' '5d']
# ['Ks' 'Kd'] ['Kh' 'Tc' 'Ts' 'Kc' '5d']
# ['Ks' 'Qd'] ['Qs' '7d' '8s' 'Qc' 'Qh']
# ['9s' '9d'] ['8h' '9h' '5s' '9c' 'Kh']
# 76000
# ['Jc' 'Js'] ['3d' 'Jh' 'Jd' '3h' '9h']
# ['7h' '7c'] ['7d' '7s' '3c' 'Jd' '6h']
# ['8h' 'Kd'] ['Kh' '3h' 'Ks' '5h' 'Kc']
# ['Qd' 'Td'] ['Qs' 'Qc' 'Qh' '9h' '8c']
# ['9c' '9d'] ['5d' '8s' '9s' '9h' '8h']
# ['3c' '3h'] ['Ah' '3s' '6h' 'Qh' '3d']
# ['Ac' 'Ts'] ['5d' 'Ad' 'Td' 'As' 'Ah']
# ['5d' '5h'] ['Ah' 'Qc' '5c' 'Kh' '5s']
# ['8c' '8h'] ['Qd' '8s' '8d' 'Ah' '7s']
# ['Qd' 'Qs'] ['8h' 'Qc' '2d' 'Js' 'Qh']
# 77000
# ['7s' '7c'] ['Ts' '7h' 'Td' 'Ah' '7d']
# ['Jc' 'Jd'] ['Tc' 'Js' '4s' 'Jh' 'Ad']
# ['Th' 'Jh'] ['Jd' '8c' 'Js' '7h' 'Jc']
# ['As' 'Qd'] ['3s' 'Qs' 'Qc' '6h' 'Qh']
# ['2h' '5h'] ['8d' '3h' 'Ac' '4h' '6h']
# ['Ac' 'Td'] ['8d' 'Ts' 'Tc' 'Qs' 'Th']
# ['Qc' 'Jh'] ['8d' 'Js' '2s' 'Jd' 'Jc']
# ['8s' '7d'] ['8h' '5h' '8d' '6c' '8c']
# ['Ac' 'Jd'] ['Ah' 'Ad' 'Js' '2s' 'As']
# ['7s' '7c'] ['7h' '3s' '7d' 'Kd' '5s']
# ['Qc' '8h'] ['Qs' '5d' '3c' 'Qh' 'Qd']
# 78000
# ['Ts' 'Td'] ['Jh' 'Th' 'Tc' '2h' '6d']
# ['5h' 'Td'] ['Th' 'Tc' 'Ts' '5c' '4s']
# ['Ts' 'Js'] ['Qs' 'Ks' 'As' '4d' '7d']
# ['Ac' '4d'] ['4c' '4h' '5d' '4s' 'Ts']
# ['Td' '7s'] ['7h' '9d' '7c' '5s' '7d']
# ['6s' '9s'] ['7s' '8s' 'Ts' '2c' '3c']
# 79000
# ['8d' '8c'] ['8s' '4d' '7c' '7d' '8h']
# ['8h' '7s'] ['8s' '8d' '3d' '8c' '6c']
# ['8s' '8d'] ['6h' '8c' '2h' '8h' '5s']
# ['9c' '9s'] ['9h' '3c' 'Ts' '2s' '9d']
# ['5h' '5s'] ['Jc' '5d' 'Kh' '8h' '5c']
# ['Ks' 'Kh'] ['Kc' 'Kd' 'Th' 'Qh' 'Ts']
# 80000
# ['4s' '4c'] ['Qh' '5h' '4h' '8d' '4d']
# ['Kc' 'Kh'] ['6d' '4h' 'Kd' 'Qd' 'Ks']
# ['7c' '7d'] ['6h' 'Qs' '8d' '7h' '7s']
# ['9c' '9h'] ['6s' '9d' '9s' 'Ac' 'Jc']
# ['As' 'Ac'] ['7h' '3h' 'Qs' 'Ad' 'Ah']
# ['Td' 'Tc'] ['9c' '5c' 'Jd' 'Th' 'Ts']
# ['9h' '9c'] ['9d' '9s' 'Jd' '8d' 'Ah']
# ['4s' '8s'] ['6s' '5s' 'Ks' '6d' '7s']
# ['Kd' 'Tc'] ['5c' '7s' 'Th' 'Td' 'Ts']
# 81000
# ['Jd' 'Ac'] ['Jh' 'Js' '9c' '5s' 'Jc']
# ['7h' 'Kc'] ['7c' '7s' '4s' '7d' 'Td']
# 82000
# ['3c' 'Qc'] ['3d' '3h' '3s' 'Qh' '2c']
# ['7s' '7h'] ['7d' '3h' '7c' 'Kh' 'Ks']
# ['Qd' 'Td'] ['6s' 'Th' 'Ts' 'Tc' '7d']
# ['2h' '2c'] ['Js' '2s' 'Jd' '6h' '2d']
# ['Qh' 'Ts'] ['Qs' 'Qd' 'Qc' '9d' '3h']
# ['Jd' '6c'] ['6d' '7s' '6h' '6s' '2d']
# ['Kc' 'Ac'] ['8h' 'Jc' 'Qc' 'Tc' '5d']
# ['Jd' 'Td'] ['Qh' 'As' '8d' '9d' 'Qd']
# 83000
# ['Qd' 'Qs'] ['5d' 'Qh' '6h' 'Qc' 'Th']
# ['2s' '2d'] ['2c' '6c' '2h' '7h' 'Qc']
# ['Th' '4s'] ['4c' '9h' '4h' '4d' 'Td']
# ['2s' '3s'] ['4s' '5s' 'Td' 'Ac' 'As']
# ['As' 'Ah'] ['2d' 'Ad' '4d' 'Ac' '5d']
# ['3d' '3s'] ['3h' '4d' 'Td' '6d' '3c']
# ['9d' '9s'] ['9h' '2s' 'Js' '9c' 'Qd']
# 84000
# ['Jh' '7d'] ['7c' '7h' '5h' '9h' '7s']
# ['7h' '4d'] ['4c' '4s' '5d' '7c' '4h']
# ['4h' '3h'] ['5h' '2h' '9c' '6h' '5c']
# ['Jd' '9s'] ['Js' 'Jh' '5h' 'Jc' '2d']
# ['Ts' '4s'] ['4d' '5d' '9d' '4c' '4h']
# 85000
# ['Ad' 'Ac'] ['Kc' 'Ah' '5s' '9d' 'As']
# ['7c' '7h'] ['Kc' '7d' 'Qs' '7s' '2c']
# ['4d' 'Qs'] ['9h' '4s' '4h' '2c' '4c']
# ['7s' '5s'] ['8d' '8s' '5h' '6s' '4s']
# ['8d' '9d'] ['7d' '5d' '6s' 'Jd' '6d']
# ['9h' '9s'] ['7s' '9c' '4d' '5c' '9d']
# ['4h' '7h'] ['Tc' '6h' '9s' '3h' '5h']
# ['9h' '9s'] ['9d' '7d' '4c' 'Kh' '9c']
# ['9c' '9d'] ['9h' '5d' '6c' 'Jd' '9s']
# 86000
# ['8d' '8h'] ['2h' '9s' 'As' '8s' '8c']
# ['2s' '2d'] ['8h' '3h' '2h' '3s' '2c']
# ['2s' '2d'] ['Jd' '7s' '2h' '8h' '2c']
# ['5s' '5d'] ['6h' '5h' '3h' 'Qh' '5c']
# ['5d' 'Qc'] ['7c' '5c' '5s' 'Qd' '5h']
# ['6d' 'Qh'] ['9s' '6h' '5d' '6c' '6s']
# ['Th' 'Jh'] ['Ts' 'Ah' '4s' 'Kh' 'Qh']
# ['5d' 'Qc'] ['5s' '6h' '5h' '5c' '6s']
# ['8h' '6s'] ['3d' '6c' '6d' '2s' '6h']
# 87000
# ['As' '4s'] ['7s' '9c' '2s' '3s' '5s']
# ['Ac' '6c'] ['Kd' '6s' '6h' '9h' '6d']
# ['Kd' 'Kh'] ['Jh' '4c' '2c' 'Ks' 'Kc']
# ['8h' '4h'] ['6h' 'Jd' '7h' '5h' '4c']
# ['9s' '9c'] ['9d' '6d' '5c' 'Kc' '9h']
# ['5s' '5c'] ['3h' '5h' 'Ac' '9c' '5d']
# ['6c' '9c'] ['4c' '7c' '5d' 'Tc' '8c']
# ['9d' '5s'] ['2h' '5d' '5h' '5c' '7s']
# ['4h' '4d'] ['4c' '2s' '4s' 'Ts' 'Jh']
# ['8h' 'Kh'] ['Ks' '7c' '5s' 'Kd' 'Kc']
# ['2s' 'Qd'] ['2h' '2d' '2c' '4c' '7c']
# 88000
# ['9d' '9c'] ['9s' 'Qc' '9h' 'Ks' 'Kd']
# ['Jd' 'Js'] ['Qs' 'Jh' 'Jc' '5h' 'Ad']
# ['Qs' '8h'] ['Qd' 'Qc' '8d' '6s' 'Qh']
# ['Ad' 'Td'] ['Kd' 'Jd' 'Kc' 'Qd' 'Qh']
# ['9d' '9s'] ['Th' '9h' '3s' '4s' '9c']
# ['Qc' 'Qd'] ['2c' '8d' 'Qs' 'Qh' 'Ad']
# ['9s' 'Qd'] ['4c' 'Qh' 'Qs' 'Qc' '2d']
# 89000
# ['8d' 'Ac'] ['2d' '8h' '8s' '8c' '9s']
# ['6h' 'Ac'] ['Kc' 'Jd' '6s' '6d' '6c']
# ['As' '7s'] ['7d' '7c' '7h' '6s' 'Qd']
# ['Tc' 'Td'] ['Ts' 'Th' '5d' '2h' '4s']
# ['Td' '6h'] ['4d' '6c' '6s' '6d' '9c']
# ['6d' '7d'] ['5h' '5d' '3d' '4d' '3s']
# ['3d' '3c'] ['6h' '2d' 'Td' '3h' '3s']
# ['Td' '6s'] ['Ts' '6d' 'Th' '5c' 'Tc']
# ['5c' '5h'] ['Ts' '5s' 'Td' 'Th' '5d']
# ['Qd' '7c'] ['7h' '5h' '7d' 'Ts' '7s']
# ['Qh' 'Qc'] ['3h' '6d' 'Qs' 'Qd' '6c']
# ['As' 'Js'] ['Qs' 'Ks' 'Ts' 'Jh' '9d']
# 90000
# ['6s' '6d'] ['Ah' '4h' 'Tc' '6c' '6h']
# ['3d' '3h'] ['5h' 'Kc' '3s' '3c' 'Jc']
# ['Ac' '7h'] ['4s' '7d' '7s' '5h' '7c']
# ['9c' 'Ad'] ['Qc' '9s' '9d' 'Kh' '9h']
# 91000
# ['Qh' 'Qs'] ['Qd' 'Qc' 'Tc' '8c' '9h']
# ['2d' '2c'] ['2h' 'Kc' '2s' '8d' '3h']
# ['6d' 'Jc'] ['9s' '6h' '6c' '4d' '6s']
# ['5s' '8s'] ['6s' 'Ah' '9s' '3c' '7s']
# ['6h' '6s'] ['Td' 'Ac' '6d' '6c' '9h']
# ['8d' '8h'] ['2s' '8c' 'Kd' 'Ks' '8s']
# ['Qd' 'Kc'] ['Qs' 'Qc' 'Qh' '4c' 'Td']
# ['3d' '2d'] ['Td' '5d' '4d' '6c' '6d']
# ['3d' '3h'] ['5c' '3s' '3c' 'Ac' '8d']
# ['Tc' 'Jh'] ['2d' 'Jd' 'Jc' '9s' 'Js']
# ['5c' '5h'] ['5d' 'Ad' 'Ah' '5s' 'Ks']
# ['Kh' '2d'] ['2c' 'Th' '2s' '9s' '2h']
# ['2d' 'Qc'] ['Jd' '2s' '2c' 'Qh' '2h']
# ['Th' '3s'] ['4c' '3c' '3h' '3d' '7c']
# ['As' 'Ac'] ['9d' 'Ad' 'Ah' 'Ks' '6d']
# 92000
# ['8s' 'Qs'] ['Js' '7s' '9s' 'Ts' 'Td']
# ['4d' '6d'] ['Qh' 'Kd' '3d' '7d' '5d']
# ['Ks' 'Kh'] ['8c' 'Kc' '3h' 'Jc' 'Kd']
# ['2s' 'Ah'] ['2h' '2c' 'Th' '6c' '2d']
# ['Qc' '9s'] ['Qs' 'Qd' 'Qh' '4s' '3s']
# ['Qh' '6h'] ['Qs' '5s' 'Qc' 'Qd' '4c']
# ['9c' 'Kh'] ['4h' 'Ks' 'Kc' 'Kd' '7s']
# ['Kh' 'Jd'] ['Jc' '7d' 'Jh' '8c' 'Js']
# ['Ad' '5s'] ['4h' 'Ah' '5c' '5d' '5h']
# 93000
# ['Js' 'Kc'] ['Jh' 'Qh' '2h' 'Jc' 'Jd']
# ['5h' '5d'] ['5s' '2h' '6d' '9h' '5c']
# ['Js' '7h'] ['5s' '7c' '7s' 'Th' '7d']
# ['Ah' '7h'] ['6d' '5s' 'Ac' 'Ad' 'As']
# ['8d' '8s'] ['8h' '3h' 'Js' '8c' '5d']
# ['3d' '3s'] ['3c' '9h' '3h' 'Jh' 'Jd']
# ['8h' 'Js'] ['3d' '9h' '8d' '8s' '8c']
# 94000
# ['5c' '9c'] ['6c' '7c' '8c' 'Jc' '3c']
# ['Kd' 'Ah'] ['Kh' '6s' 'Ks' '2c' 'Kc']
# ['Ks' 'Kh'] ['Kc' '9d' 'Ts' 'Jd' 'Kd']
# ['7s' '7d'] ['7h' '4d' '6h' 'As' '7c']
# ['Kd' '3d'] ['Th' 'Qd' '3h' '3s' '3c']
# ['7h' '7c'] ['Kd' '5d' '7d' '7s' 'Td']
# ['Th' '5c'] ['3d' '5d' '7c' '5s' '5h']
# ['Jd' 'Qs'] ['6h' 'Jc' 'Jh' 'Js' '4d']
# ['Jh' 'Qc'] ['Qh' 'Qd' '2s' 'Qs' '2h']
# ['9s' 'Ts'] ['2d' 'Kc' '8s' 'Js' '7s']
# ['Ah' 'Ad'] ['7s' 'Ac' 'As' '3c' 'Td']
# ['Qs' 'Qc'] ['Ah' 'Qh' 'Ks' '8h' 'Qd']
# ['7s' '7c'] ['Qc' '7d' '6d' 'Kc' '7h']
# 95000
# ['7d' '7c'] ['7s' 'Ac' '5d' '7h' '8h']
# ['6s' '9s'] ['Ts' '8s' '5s' '7s' '3h']
# ['4c' '4s'] ['Td' '8h' '9h' '4h' '4d']
# ['Jd' 'Jh'] ['Js' 'Jc' '6c' '7c' '3c']
# ['Qc' 'Qd'] ['Qs' '5s' 'Kh' 'Qh' '8s']
# ['4d' '4c'] ['3c' '4h' '8h' '8d' '4s']
# ['Qc' 'Ks'] ['5h' 'Kd' 'Th' 'Kh' 'Kc']
# ['9h' '9d'] ['9s' '6c' '2c' '4s' '9c']
# ['Jc' 'Jd'] ['7h' 'Jh' '3c' 'Qd' 'Js']
# ['Kc' 'Ks'] ['Kd' 'Kh' '8c' '8d' '3d']
# 96000
# ['Js' 'Jc'] ['Jh' 'Jd' '5c' '6d' '8h']
# ['9c' '8c'] ['7c' '6c' 'Tc' 'As' 'Qh']
# ['7c' '8s'] ['7h' '3c' '7d' '7s' '3d']
# ['Qh' 'Th'] ['4s' '9h' 'Jc' 'Jh' '8h']
# ['3h' '3c'] ['8s' '5d' '3d' 'Tc' '3s']
# ['8h' '9h'] ['Jh' '7h' '5s' 'Th' '6s']
# ['Kd' 'Kc'] ['8d' '6h' 'Ac' 'Kh' 'Ks']
# ['Ts' '8h'] ['8s' '8d' '5s' '8c' '6s']
# ['7s' '6s'] ['Ts' '8s' '4s' 'Tc' '5s']
# 97000
# ['Qs' 'Qc'] ['5s' '3h' '7s' 'Qd' 'Qh']
# ['Ts' 'Tc'] ['Th' 'Qd' 'Td' 'Ac' '8s']
# ['Kd' 'Kc'] ['3h' '3d' 'Kh' '4h' 'Ks']
# ['8s' '7s'] ['6s' '3h' '9s' 'Jd' '5s']
# ['5c' 'Tc'] ['4s' '7c' '5d' '5h' '5s']
# ['7h' '4h'] ['6h' '5h' 'Ts' '3c' '3h']
# ['3d' '8s'] ['5c' '3c' '6d' '3s' '3h']
# ['2h' '4h'] ['4c' '3h' '6h' 'Ad' '5h']
# ['Jc' 'Kc'] ['Qc' 'Tc' '9c' '4d' '3s']
# ['4s' 'Ac'] ['Kc' '4d' 'Tc' '4h' '4c']
# ['Qs' '4h'] ['Qc' '4d' '4s' '4c' '2d']
# 98000
# ['9s' '9c'] ['Kh' '9d' '9h' '7s' 'Ah']
# ['7c' '7h'] ['Jd' 'Ks' 'Qd' '7s' '7d']
# ['Qs' 'Qd'] ['9c' 'Qc' 'Qh' '2d' '6h']
# ['9d' 'Jd'] ['Kd' 'Js' 'Td' 'Qd' '2c']
# ['3d' '3c'] ['Jh' '3h' '3s' '5h' '7d']
# ['9h' '9d'] ['7s' '3d' '9c' '9s' '3s']
# ['6s' '6c'] ['6d' '5s' '4c' '6h' '3h']
# ['6h' 'Qd'] ['6s' 'Ts' '6c' '6d' 'Qc']
# 99000
# ['4c' '4h'] ['Th' 'Qc' '4d' '8s' '4s']
# ['Kd' '9d'] ['Tc' 'Td' 'Qd' 'Jd' 'Kc']
# ['Td' 'Th'] ['Ts' 'Jc' '4h' 'Ah' 'Tc']
# ['Tc' 'Td'] ['Ts' 'Th' 'Jd' 'Ac' '7h']
# ['8h' 'Th'] ['Ac' 'Qh' '9h' 'Jh' 'Qs']
# ['Kd' 'Ac'] ['Kh' 'Td' 'Kc' '8c' 'Ks']
# ['Js' '9s'] ['Ts' '8s' '7s' '5c' '9d']
# 100000
# ['6s' '5s'] ['2s' '6h' '4s' '3s' '8d']
# ['As' 'Ac'] ['6d' 'Ad' 'Kd' 'Td' 'Ah']
# ['2c' '4c'] ['Ac' '6d' '3c' '7h' '5c']
# ['5c' '5h'] ['5d' '7h' '9h' 'Td' '5s']
# ['Jd' '6c'] ['7d' '6h' '6s' '6d' '9h']
# ['Ad' 'Th'] ['7s' 'Td' 'Tc' '6s' 'Ts']
# ['4s' '4h'] ['Th' '4d' '6d' '4c' '5c']
# ['Tc' 'Ts'] ['2s' 'Ah' 'Th' '2c' 'Td']
# 101000
# (0, 0.0, [])
